# %% [markdown]
# <a href="https://colab.research.google.com/github/alcarvalhox/Projeto-Eddy-Current/blob/master/EC_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import math
import os
import sys
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.image as mpimg 
from matplotlib.pyplot import imshow
from numpy import *
import numpy as np
import scipy.io
from scipy import signal
from scipy.signal import medfilt
import seaborn as sns
import pywt
import csv
from PIL import Image
import argparse
import cv2 
from numpy import asarray
from numpy import savetxt
from PIL import Image
from numpy import asarray
import pickle as pkl
from prettytable import PrettyTable
from prettytable import from_csv
from prettytable import from_html
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
from keras.preprocessing.image import img_to_array
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
from keras.utils import plot_model
from keras.models import load_model
import pylab as pl
from google.colab import files
from google.colab.patches import cv2_imshow
from IPython.display import Image, display


#################################################
from google.colab import drive
drive.mount("/content/drive/")

#################################################
try:
  path = '/content/drive/My Drive/Projeto Eddy Current/ProjetoFinal'
  os.chdir(path)
except:
  print("Erro ao carregar diretorio no drive. Usado para drive compartilhado")

#################################################
print("Sistema preparado para rodar!")
print(datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S"))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Sistema preparado para rodar!
# 15-09-2020 16:41:50

# %% [markdown]
# # **Bloco de Classes**

# %%
#######################################
#### Leitura e Abertura de Arquivo ####
#######################################

class carrega_arquivo:
  def __init__(self):
    pass 

  def le_arquivo (self ,Path,File):
    #### Lê Arquivo .txt 
    with open(Path +'/'+ File, 'r') as f:
      # Usando a expressão regular para o separador indicando que eles são os espaços em branco
      df = pd.read_table(f, sep='\s+')
      df=df.replace(np.nan,0)
            

        # lista os cabeçalhos    
      cabecalho=df.columns

        # atribui a coluna do gráfico no indíce da coluna
      c = cabecalho[2]
        # define o comprimento da coluna
      a = len(df[cabecalho[2]])
        
        # cria vetor com quantidade de pontos
      x = np.arange(a)
        
        # define quantidade de linhas (pontos) e colunas
      linha = a
      coluna = 1
      
      return df[c]


##############################################################

#######################################
####        Filtra Sinais          ####
#######################################



class filtro:
  def __init__(self):
    pass

############### Spikes ################

  def tira_spikes(self,teste):

    resultado = []
    grad = (np.gradient(teste))
    valores = [int(val) for val in grad]

    for x in range (1,len(teste)):
        resultado.append(teste[x])

    for x in range (1,len(teste)):
        if abs(valores[x]) > (200):
            for x in range (x,(x+500)):
                resultado[x]=0 # Sinal Original Filtrado 
                
    resultado=signal.medfilt(resultado,kernel_size=11) 
    
    return resultado

############### Filtro  Media ################
  def filtro_media(self,sinalf,picos,janela2,mediainf,mediasup):

    (n,qsinais) = sinalf.shape  
    sinal=sinalf 
    contsinais =0
    janela4 = []
    picos4 = []

    for x in range(0,qsinais):
        if (np.mean(sinal[:,x])> mediainf) and (np.mean(sinal[:,x])< mediasup):
            janela4.append(janela2[x])
            picos4.append(picos[x])
            contsinais=contsinais+1
            
    #%%%% Cria matriz sinalfinal        
    sinalfinal = np.zeros(((amostras+1),(contsinais)))    

    #%%%% Coloca sinais filtrados por média na matriz sinalfinal
    qsinais2=0
    for x in range(0,(contsinais)):
        if (np.mean(sinal[:,x])> mediainf) and (np.mean(sinal[:,x])< mediasup):
            
            sinalfinal[:,qsinais2]=sinal[:,x]
            qsinais2=qsinais2+1

    return sinalfinal,janela4,picos4

  ############### Filtro  FFT ################
  def filtro_fft(self,sinalfinal,picos4,janela4):  

    (n,qsinais3) = sinalfinal.shape
    contasinais2 = 0
    janela5 = []
    picos5 = []

    for x in range(0,qsinais3):
        a=(max(np.fft.fft(sinalfinal[:,x])))
        #if a.imag != 0:
        if a.imag < 2000:    
            janela5.append(janela4[x])
            picos5.append(picos4[x])
            contasinais2=contasinais2+1
            
    # Cria matriz sinalfinal2
    sinalfinal2 = np.zeros(((amostras+1),(contasinais2)))

    # Coloca sinais filtrados por FFT na matriz sinalfinal2
    qsinais4 = 0

    for x in range(0,qsinais3):
        a=(max(np.fft.fft(sinalfinal[:,x])))
        #if a.imag != 0:
        if a.imag < 2000:    
            sinalfinal2[:,qsinais4] = sinalfinal[:,x]
            qsinais4=qsinais4+1    

    return sinalfinal2,janela5,picos5
  

################ Filtro Zerocross #################
  def filtro_zerocross(self,sinalfinal2,picos5,janela5,zerocross):

    (n,qsinais5) = sinalfinal2.shape
    contasinais3 = 0
    janela6 = []
    picos6 = []
    zero_x = 0

    for x in range(0,qsinais5):
        zero_x = 0
        for idx in range(1,(amostras-1)):
            if sinalfinal2[idx,x] < 0 and sinalfinal2[(idx+1),x] > 0:
                zero_x +=1
            if sinalfinal2[idx,x] > 0 and sinalfinal2[(idx+1),x] < 0:
                zero_x +=1
                
        if zero_x > zerocross:
            janela6.append(janela5[x])
            picos6.append(picos5[x])
            contasinais3=contasinais3+1
            
    # Cria matriz sinalfinal2
    sinalfinal3 = np.zeros(((amostras+1),(contasinais3)))

    # Coloca sinais filtrados por ZeroCross na matriz sinalfinal2
    qsinais6 = 0

    for x in range(0,qsinais5):
        zero_x = 0
        for idx in range(1,(amostras-1)):
            if sinalfinal2[idx,x] < 0 and sinalfinal2[(idx+1),x] > 0:
                zero_x +=1
            if sinalfinal2[idx,x] > 0 and sinalfinal2[(idx+1),x] < 0:
                zero_x +=1
        if zero_x > zerocross: 
            sinalfinal3[:,qsinais6] = sinalfinal2[:,x]
            qsinais6=qsinais6+1

    return sinalfinal3,janela6,picos6


################ Filtro Gradiente #################
  def filtro_gradiente(self,sinalfinal3,picos6,janela6,gradiente):

    (n,qsinais7) = sinalfinal3.shape
    contasinais4 = 0
    janela7 = []
    picos7 = []


    for x in range(0,qsinais7):
        
        if max(abs(np.gradient(sinalfinal3[:,x]))) < gradiente:
                
                janela7.append(janela6[x])
                picos7.append(picos6[x])
                contasinais4=contasinais4+1
                    

    # Cria matriz sinalfinal4
    sinalfinal4 = np.zeros(((amostras+1),(contasinais4)))
                    
    # Coloca sinais filtrados por Diferença de Constante na matriz sinalfinal4
    qsinais8 = 0

    for x in range(0,qsinais7):
        
            if max(abs(np.gradient(sinalfinal3[:,x]))) < gradiente:
                
                    sinalfinal4[:,qsinais8] = sinalfinal3[:,x]
                    qsinais8=qsinais8+1 
                    
    
    sinalfinal = sinalfinal4
    qsinais2 = qsinais8

    return sinalfinal4,janela7,picos7

######################################################################

#######################################
####     Padronização do Sinal     ####
#######################################

class padroniza_sinal:
  def __init__(self):
    pass

  def padroniza(self,resultado) :
    media = np.mean(resultado)
    sinalpadrao = (resultado-media)/np.std(resultado) 
    return sinalpadrao

#########################################################################

#######################################
####         Plotar Gráficos       ####
#######################################


class ClassePlote:

  def __init__(self):
    pass


#########################################################
  # Função realiza o plote de vetor x e y
  # Parametros:
  # - VetorX
  # - VetorY
  # - Xlabel
  # - Ylabel
  # - legend 
#########################################################
  def ploteLinha(self,VetorY, Xlabel, Ylabel, Legend):
    try:
      VetorX = list(range(1,(len(VetorY)+1)))
      plt.plot(VetorX, VetorY) #, linestyle='--', color="k")  
      #plt.scatter(VetorX, VetorY, color="r", marker="o", label=Legend)     
      plt.xlabel(Xlabel)
      plt.ylabel(Ylabel)
      plt.title(Legend)
      plt.grid(False)
      plt.show()
    except:
      print("Erro no metodo ploteLinha: na Linha {}".format(sys.exc_info()[-1].tb_lineno))
    
    
#########################################################
#Função realiza o plote histograma 1D
# Parametros: 
#########################################################
  def plotHistograma1D(self, Dado, Nbins, BoolDensity, Xlabel, Ylabel, Legend):
    try:
      bins =  OperadorPlot.hist(Dado, Nbins, density=BoolDensity, label=Legend)
      OperadorPlot.xlabel(Xlabel)
      OperadorPlot.ylabel(Ylabel)
      OperadorPlot.legend()       
      OperadorPlot.grid(True)
      OperadorPlot.show()
    except:
        print("Erro no metodo plotHistograma1D: na Linha {}".format(sys.exc_info()[-1].tb_lineno))
    
    
#########################################################
#Função realiza o plote de vetor x e y
# Parametros: 
#########################################################
  def getRandomVector(self, lenght, mu, sigma): 
    try:
        return (mu + sigma * np.random.randn(lenght))
    except:
        print("Erro no metodo getRandomVector: na Linha {}".format(sys.exc_info()[-1].tb_lineno))


#########################################################
#Função realiza o plote de sinais filtrados
# Parametros: 
#########################################################
  def plotar_sinais_filtrados(self,sinalfinal4,comprimento,picos7,janela7):
    
    comp=comprimento
    qsinais2 = len(sinalfinal4[0])
    sinalfinal=sinalfinal4
    linha = 0
    q = 0
    contador = 1
    linhas = range(0,(round(sinalfinal.shape[1]//2)))

    k= round((qsinais2/4)+1)
    if k == 1:
        k = 4
    k = round((qsinais2/4)+1)    


    #plt.rcParams['figure.figsize']=(10,10) 
    #plt.subplots_adjust(hspace = 1.4)
    fig, ax = plt.subplots((k), 4,figsize=(16.4,8.6))
    fig.tight_layout()

    for x in range(1,(sinalfinal.shape[1]+1)):
        
                                
            plt.rcParams['xtick.labelsize'] = 5
            plt.rcParams['ytick.labelsize'] = 5 
        
            
            
            plt.subplot(ax.shape[0],ax.shape[1],(x))
            plt.subplots_adjust(hspace = 1.4)
            plt.plot(range(1,(amostras+2)),sinalfinal[:,(x-1)])
            a=str(x)
            b=str(janela7[x-1])
            c=str(int(picos7[x-1]))
            e=str(int(comp[x-1]))
            d=' Coord '
            y=' Sinal '
            z= ' Máximo '
            w= ' Comprimento '
            titulo = d + b + y + a + z + c + w + e 
            plt.title('Coord:  Sinal:  Máximo:  Comprimento:\n '+ b+'   '+a+'     '+c+'            '+e+'         ',fontsize=12)
            plt.show





#########################################################################

#######################################
####         Identifica Threshold   ###
#######################################

class Ident_thres:
  def __init__(self):
    pass

  def threshold_sinal(self,opcao,amostras,sinalvet,limite):
    #%%%% a é o número de pontos do sinal
    #%%%% Delay são os número de pontos que irão retroagir
    #%%%% Amostras é o tamaho da janela dos sinais identificados
    #%%%% Limite é valor do threshlod para filtrar ruídos iniciais

    a=len(sinalvet)

    if opcao == 1:
        a1=delay + 30000 # + 3000 - RODO 
    else:
        a1=delay + 10000
        
    t=1  
    cont1=1
    janela=[]


    while (a1<(a-amostras)):
        if (abs(sinalvet[a1]) >= limite):

            #%%%% define a próxima janela a ser analisada
            janela.append(a1)
            a1=a1+amostras

        if (abs(sinalvet[a1]) < limite):

            #%%% desconsidera pontos abaixo do threshold e analisa o próximo ponto   
            a1=a1+1 

    return janela          


#########################################################################

#######################################
####         Destaca Sinais         ###
#######################################


class sinais:
  def __init__ (self):
    pass

  def  destaca_sinais(self,janela,amostras,sinalvet):

    k=len(janela) # quantidade de janelas                         
    sinalf=np.zeros(((amostras+1),k))
    picos=np.zeros(k)
    conta=0                    
    janela2=[]


    while (conta<=(k-1)):
    
        for i in janela:
            if i > delay: 
            
                
                #%%%% destaca o sinal do sinal principal e inclui no vetor sinalf         
                #sinalf[:,conta]=sinalvet[(i-delay):(i+amostras-delay+1)]
                pico=max(abs(sinalvet [(i-delay):(i+amostras-delay+1)]))

                for x in range ((i-delay),(i+amostras-delay+1)):
                  if abs(sinalvet[x]) == pico:
                    picos[conta]=x
                
                inicio = int(picos[conta]-(amostras/2))  
                fim = int(picos[conta]+(amostras/2)+1) 

                dif=fim-inicio 

                while dif != (amostras+1):
                  if dif < (amostras+1):
                    fim=fim+1
                    dif=fim-inicio 
                  if dif > (amostras+1):
                    fim=fim-1
                    dif=fim-inicio   


                sinalf[:,conta]= sinalvet[inicio:fim]  
                    
                #%%%% aumenta o contador para armazenar o próximo sinal no vetor
                conta = conta + 1
                janela2.append(i)
                #%%%% define a próxima janela a ser analisada
                #a1=a1+amostras
     
    return sinalf,janela2,picos

##############################################
###### Mede Comprimento dos Sinais ###########
##############################################

class mede_comprimento:
  def  __init_ (self):
    pass

  def comprimento_sinal(self,sinalfinal):

    
    qsinais2=len(sinalfinal[0])
    comp=np.zeros(qsinais2)
    profundidade=np.zeros(qsinais2)

    if opcao == 1: # Rodo
      constante = 9
    if opcao == 2: # Manual
      constante = 30

    
    energia = np.zeros(((amostras+1),(qsinais2)))
    #energia2 = np.zeros(((amostras+1),(qsinais2)))
    sinalpadronizado = np.zeros(((amostras+1),(qsinais2)))
    #sinalpadronizado2 = np.zeros(((amostras+1),(qsinais2)))
    comp1=np.zeros(((qsinais2)))
    #comp2=np.zeros(((qsinais2)))


    a1=0
    a2=0



    for indice in range(0,qsinais2):
        #print('SINAL ',indice)
        q=sum(abs(sinalfinal[:,indice]**2))
        #print('Energia total sinal 1','(',indice,')',' = ',q)

        #plt.plot(sinalfinal[:,indice])
        #plt.title('Sinal '+ str(indice))
        #plt.show()

        for x in range(1,len(sinalfinal[:,indice])):
          qq=sum(abs(sinalfinal[1:x,indice]**2))
          energia[x,indice]=qq
            
          
            
        sinalpadronizado[:,indice] = (energia[:,indice] - np.min(energia[:,indice]))/np.ptp(energia[:,indice])
          
          
            
        flag1=0
        flag2=0

          
        for x in range(1,len(sinalpadronizado[:,indice])):

          if  (sinalpadronizado[x,indice])>(0.10) and (flag1==0):
              
            #print('x',x)
            a1=x 
            #print('a1',a1)
            flag1=1

          if (sinalpadronizado[x,indice])>(0.95) and (flag2==0): 
              
            #print('x',x)
            a2=x
            #print('a2',a2)
            flag2=1

                
        comp1[indice]=a2-a1 

        comp[indice]= round(((a2-a1)/constante),2)
        maximo=max(sinalfinal[:,indice])
        minimo=min(sinalfinal[:,indice])
        profundidade[indice]=round(((maximo-minimo)/0.8),2)
      
           
    return sinalfinal,comp,profundidade 
      #a1 Início do sinal) 
      #a2 Fim do sinal
      # a2-a1 Comprimento do Sinal 
      # w Energia mínima do sinal  
      # x Coordenada da Energia Mínima
      #plt.show()
      #plt.plot(sinalfinal[:,indice])
      #plt.plot(abs(sinalfinal[:,indice])**2)
      #plt.show()
      #plt.plot(sinalfinal[a1:a2,indice])
      #plt.show()


##########################################################
######## Executa a Transformada Wavelet do Sinal #########
##########################################################

class transf_wavelet:
  def __init__(self):
    pass

  def wavelet_sinal(self,nome_da_wavelet,escalas,cmap,amostras,caminho_figuras,sinalfinal):

    #familia2=['cgau1','cgau2','cgau3','cgau4','cgau5','cgau6','cgau7','cgau8','cmor','fbsp','gaus1','gaus2','gaus3','gaus4','gaus5','gaus6','gaus7','gaus8','mexh','morl','shan']
    waveletname = nome_da_wavelet
    #waveletname = 'cmor1.5-1.0'
    #escalas = 50
    #cmap = 'coolwarm'
    time = np.arange(0,(amostras+1))
    scales = np.arange(1, escalas)
    #path ='C:/Projeto Eddy Current/Supervisionado/Sinais/teste/imagemmorl'
    path = caminho_figuras 
    #path = 'C:/Projeto Eddy Current/Sinais_Coletados/Banco de Dados/Medidas_SVTS/SD/figuras3/'
    dt = 1
    #for x in range(0,len(familia2)):
    #for x in range(15,16):                       
    for x in range(0,len(sinalfinal[1])):       
        [coefficients, frequencies] = pywt.cwt(sinalfinal[:,(x)], scales, familia2[8], dt)
        power = (abs(coefficients)) ** 2
        period = 1. / frequencies
        levels = [0.03125,0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8,16,32]
        contourlevels = np.log2(levels)

        a=str(x+1)
        b = familia2[8]
        #l = str(3)
        #b = waveletname
        caminho = path+'/'+'teste'+a+'.jpg'
        im2 = plt.contourf(time, np.log2(period), np.log2(power), contourlevels, extend='both',cmap=cmap)

        path2 = '/content/drive/My Drive/Projeto Eddy Current/ProjetoFinal/t_wavelet1'
        data = asarray(im2)
        nome = path2+'/'+'data'+a+'.txt'
        save = True
        fileObject = open(nome, 'wb')
        if save:
          pkl.dump(data,fileObject)
          fileObject.close()

        plt.axis('off')
        plt.gca().invert_yaxis()
        plt.savefig(caminho,bbox_inches='tight',transparent = "true") 
        plt.gca().invert_yaxis()  

##########################################################
#### Executa o Modelo CNN Treinado para Classificação ####
##########################################################

class modelo_cnn():
  def __init__(self):
    pass

  def classifica_sinais (self,classLabels,caminho_figuras,caminho_modelo):

    #classLabels = classlabels 

    ############################
    # Transforma Imagem em array
    ############################
    class ImageToArrayPreprocessor:
      def __init__(self, dataFormat=None):
        # store the image data format
        self.dataFormat = dataFormat

      def preprocess(self, image):
        # apply the Keras utility function that correctly rearranges
        # the dimensions of the image
        return img_to_array(image, data_format=self.dataFormat)

    ####################################################
    # Faz o preprocessamento de imagens largura x altura
    ####################################################
    class SimplePreprocessor:
      def __init__(self, width, height, inter=cv2.INTER_AREA):
        # store the target image width, height, and interpolation
        # method used when resizing
        self.width = width
        self.height = height
        self.inter = inter

      def preprocess(self, image):
        # resize the image to a fixed size, ignoring the aspect
        # ratio
        return cv2.resize(image, (self.width, self.height),
          interpolation=self.inter)
      
    ###################################
    # Carrega os dados e cria os labels
    ###################################
    class SimpleDatasetLoader:
      def __init__(self, preprocessors=None):
        # store the image preprocessor
        self.preprocessors = preprocessors

        # if the preprocessors are None, initialize them as an
        # empty list
        if self.preprocessors is None:
          self.preprocessors = []

      def load(self, imagePaths, verbose=-1):
        # initialize the list of features and labels
        data = []
        labels = []

        # loop over the input images
        for (i, imagePath) in enumerate(imagePaths):
          # load the image and extract the class label assuming
          # that our path has the following format:
          # /path/to/dataset/{class}/{image}.jpg
          #print('imagePath input :' , imagePath)
          image = cv2.imread(imagePath)
          label = imagePath.split(os.path.sep)[-2]

          # check to see if our preprocessors are not None
          if self.preprocessors is not None:
            # loop over the preprocessors and apply each to
            # the image
            for p in self.preprocessors:
              image = p.preprocess(image)

          # treat our processed image as a "feature vector"
          # by updating the data list followed by the labels
          data.append(image)
          labels.append(label)

          # show an update every `verbose` images
          if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1,
              len(imagePaths)))

        # return a tuple of the data and labels
        return (np.array(data), np.array(labels))
      

    #################################
    # Faz a validação do modelo #####
    #################################


    # construct the argument parse and parse the arguments
    #ap = argparse.ArgumentParser()
    #ap.add_argument("-d", "--dataset", required=True,
    #	help="path to input dataset")
    #ap.add_argument("-m", "--model", required=True,
    #	help="path to pre-trained model")
    #args = vars(ap.parse_args())

    # initialize the class labels
    #classLabels = ["junta_isolada","junta_seca", "solda"]
    #classLabels = classLabels 
    classLabels = ["cracking","junta","solda", "squat"]
    #classLabels = ["chef", "doctor", "engineer","farmer","firefighter","judge","mechanic","pilot","police","waiter"]
    #imagePaths = list(paths.list_images("/content/drive/My Drive/idenprof/idenprof/validacao"))

    # grab the list of images in the dataset then randomly sample
    # indexes into the image paths list
    #path_imagens = "/content/drive/My Drive/idenprof/idenprof/validacao"
    print("[INFO] sampling images...")
    #imagePaths = np.array(list(paths.list_images("/content/drive/My Drive/idenprof/idenprof/validacao")))
    imagePaths = np.array(list(paths.list_images(caminho_figuras)))
    #idxs = linspace(0,(len(imagePaths)-1),(len(imagePaths)-1),dtype=int)
    #print('imagePaths: ',imagePaths)
    #print('idxs: ',idxs)
    #idxs = np.random.randint(0, len(imagePaths), size=(15,))
    idxs = []
    for x in range(0,(len(imagePaths))):
      idxs.append(x)

    imagePaths = imagePaths[idxs]
    #print('imagePaths  depois : ',imagePaths)
    #print('idxs :',idxs)

    # initialize the image preprocessors
    sp = SimplePreprocessor(32, 32)
    iap = ImageToArrayPreprocessor()

    # load the dataset from disk then scale the raw pixel intensities
    # to the range [0, 1]
    sdl = SimpleDatasetLoader(preprocessors=[sp, iap])
    (data, labels) = sdl.load(imagePaths)
    data = data.astype("float") / 255.0

    # load the pre-trained network
    #path_modelo = "/content/drive/My Drive/idenprof/idenprof/models/weights.hdf5"
    path_modelo = caminho_modelo
    print("[INFO] loading pre-trained network...")
    model = load_model(path_modelo)

    # make predictions on the images
    print("[INFO] predicting...")
    preds = model.predict(data, batch_size=32).argmax(axis=1)
    #print('Classes :',preds)
    
    #print('Labels',labels)
    
    nome = []
    predicao = []

    # loop over the sample images
    for (i, imagePath) in enumerate(imagePaths):
    #for i in range (0,len(idxs)+1):  
      #print('i :',i)
      #print(' Comprimento de imagePaths :',len(imagePaths))
      #print('imagePath : ',imagePath) 
      #display(Image(imagePath))
      #print('Classe: ',classLabels[preds[i]])
      base=os.path.basename(imagePath)
      base2=os.path.splitext(base)[0]   
      #print(' Nome do Arquivo: ',os.path.splitext(base)[0])
      nome.append(base2)
      predicao.append(classLabels[preds[i]]) 

      
    return nome,predicao



class tabela():
  def __init__(self):
    pass

  def constroe_tabela (self,nome,predict,comprimento,profundidade): 
    # Cria a tabela
    x = PrettyTable(["Nome do Arquivo", "Classificação", "Comprimento Estimado(mm)","Profundidade Estimada(mm)"])

    # Alinha as colunas
    x.align["Nome do Arquivo"] = "l"
    x.align["Classificação"] = "l"
    x.align["Comprimento Estimado(mm)"] = "r"
    x.align["Profundidade Estimada (mm)"] = "r"
    #x.align["Longitude"] = "r"

    # Deixa um espaço entre a borda das colunas e o conteúdo (default)
    x.padding_width = 1

    x = PrettyTable()
    x.add_column('Nome do Arquivo', nome)
    x.add_column('Classificação', predicao)
    x.add_column('Comprimento Estimado(mm)', comprimento)
    x.add_column('Profundidade Estimada(mm)', profundidade)
    #x.add_column('Longitude', [])

    print(x)   


print("Classe carregada!")
print(datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S"))
# Out:
# Classe carregada!
# 15-09-2020 16:55:18

# %% [markdown]
# # **Algoritmo Principal**

# %%
##########################  Início   ##########################################

########################## Definição do caminho do arquivo ####################
Path = "/content/drive/My Drive/Projeto Eddy Current/Sinais_Coletados/Banco de Dados/Medidas_SVTS_2/JI"
#Path = "/content/drive/My Drive/Projeto Eddy Current/Sinais_Coletados/Banco de Dados/Medidas_SVTS/JI"
#Path = "/content/drive/My Drive/Projeto Eddy Current/Sinais_Coletados/Banco de Dados/6-Coleta de dados com o RD58 Ramal Paraibuna (vma20kmh) 04-09-2019"
File = "ji3_0.txt"
#File = "jti9_0.txt"
#File = "Dados_SVTS_10.txt"

##############################################################################

#########################
# Definição de Variáveis#
#########################
wavelet = 0 # Se = 1 realiza a transformada wavelet
opcao=2  #1=sinal rodo  2=sinal manual
mediasup = 4.15 #0.55
mediainf = -6.15 #-0.35
zerocross = 2
tipo_de_grafico = 'flag'
escalas = 512
familia=['haar', 'db', 'sym', 'coif', 'bior', 'rbio', 'dmey', 'gaus', 'mexh', 'morl', 'cgau8', 'shan', 'fbsp', 'cmor']
familia2=['cgau1','cgau2','cgau3','cgau4','cgau5','cgau6','cgau7','cgau8','cmor','fbsp','gaus1','gaus2','gaus3','gaus4','gaus5','gaus6','gaus7','gaus8','mexh','morl','shan']
nome_da_wavelet = familia2[8]
escalas = 50
cmap = 'coolwarm'
classLabels = ["cracking","junta","Solda", "squat"]
caminho_figuras = '/content/drive/My Drive/Projeto Eddy Current/ProjetoFinal/t_wavelet'
caminho_modelo = '/content/drive/My Drive/Projeto Eddy Current/ProjetoFinal/modelo/4classes100Ev2.hdf5'
#gradiente =  29 # 1.45 #3 sd  #9 manual #1.45 rodo
#path ='C:/Projeto Eddy Current/Supervisionado/Sinais/teste/imagem'

######################
# Opções de aquisição#
######################

if opcao == 1: # RODO 

    limite = 1 #4 #threshold superior
    limite2 = -200 #threshold inferior
    delay=800 #% RODO
    amostras=1499 # RODO
    const=20 # RODO
    gradiente = 1
    

if opcao == 2:# MANUAL 
   
    limite = 0.4#2 #1.8 #4 #0.7 (Junta) #threshold superior #0.7
    limite2 = -200 #threshold inferior
    delay=3500 #500 #250(Junta)Rodo # manual 40
    amostras=9999#7999 #2499 #799(Junta) #Rodo # manual 399
    const=20 #Rodo
    gradiente = 1

#######################################################################


####################  Leitura do Arquivo ##############################
### Cria Operador Arquivo
OperadorArquivos = carrega_arquivo()
### Recebe o arquivo lido
sinal=OperadorArquivos.le_arquivo(Path,File)

#x1=list(range(1,(len(sinal)+1)))


#####################  Filtra Spikes ###################################
### Cria Operador Filtro
OperadorFiltro=filtro()
### Recebe o arquivo sem spikes
resultado=OperadorFiltro.tira_spikes(sinal)

##################### Padroniza Sinal ###################################
### Cria Operador Padroniza Sinal
OperadorPadroniza = padroniza_sinal()
### Recebe o arquivo do sinal padronizado
sinalpadrao=OperadorPadroniza.padroniza(resultado) 


###################### Plota Sinal Principal ############################
### Cria Operador Plota Sinal
OperadorPlota = ClassePlote()
### Plota gráfico
OperadorPlota.ploteLinha(sinal,'Amostras','Valor','Sinal Original ')
OperadorPlota.ploteLinha(resultado,'Amostras','Valor','Sinal Original sem spikes')
OperadorPlota.ploteLinha(sinalpadrao,'Amostras','Valor','Sinal Padronizado')


####################### Destaca Sinais ###################################
### Cria Operador Threshold
OperadorThreshold = Ident_thres()
janela=OperadorThreshold.threshold_sinal(opcao,amostras,sinalpadrao,limite)

### Cria Operador Sinal
OperadorSinal=sinais()
### Destaca Sinais
(sinalf,janela2,picos)=OperadorSinal.destaca_sinais(janela,amostras,sinalpadrao)


###################### Filtra Sinal #########################################
### Filtro Média
(sinalfinal,janela4,picos4)=OperadorFiltro.filtro_media(sinalf,picos,janela2,mediainf,mediasup)
### Filtro FFT
(sinalfinal2,janela5,picos5)=OperadorFiltro.filtro_fft(sinalfinal,picos4,janela4)
### Filtro ZeroCross
(sinalfinal3,picos6,janela6)=OperadorFiltro.filtro_zerocross(sinalfinal2,picos5,janela5,zerocross)
### Filtro Gradiente
(sinalfinal4,picos7,janela7)=OperadorFiltro.filtro_gradiente(sinalfinal3,picos6,janela6,gradiente)


###################### Mede Sinal ############################################
### Cria Operador mede Sinal
Operador_mede_sinal=mede_comprimento()
### Mede Sinal
(sinalmedido,comprimento,profundidade)=Operador_mede_sinal.comprimento_sinal(sinalfinal4)





##################### Executa a transformada Wavelet ########################
### Cria Operador Wavelet
Operador_wavelet=transf_wavelet()
################# Faz a Transformada Wavelet do Sinal e Grava 
Operador_wavelet.wavelet_sinal(nome_da_wavelet,escalas,cmap,amostras,caminho_figuras,sinalfinal4)


###################### Plota Sinal ###########################################
### Plota Sinais Filtrados
OperadorPlota.plotar_sinais_filtrados(sinalfinal4,comprimento,picos7,janela7)


################## Faz a classificação das categorias  ################
### Cria Operador Modelo CNN
Operador_cnn=modelo_cnn()
### Faz a Classificação dos Sinais 
(nome,predicao)=Operador_cnn.classifica_sinais (classLabels,caminho_figuras,caminho_modelo)


################### Plota Tabela resumo dos sinais classificados  ############
### Cria Operador Tabela
Operador_tabela=tabela()
### Faz a Tabela
Operador_tabela.constroe_tabela (nome,predicao,comprimento,profundidade)
# Out:
# /usr/local/lib/python3.6/dist-packages/pywt/_cwt.py:117: FutureWarning: Wavelets from the family cmor, without parameters specified in the name are deprecated. The name should takethe form cmorB-C where B and C are floats representing the bandwidth frequency and center frequency, respectively (example: cmor1.5-1.0).
#   wavelet = DiscreteContinuousWavelet(wavelet)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:570: RuntimeWarning: divide by zero encountered in log2
# [INFO] sampling images...
# [INFO] loading pre-trained network...
# [INFO] predicting...
# +-----------------+---------------+--------------------------+---------------------------+
# | Nome do Arquivo | Classificação | Comprimento Estimado(mm) | Profundidade Estimada(mm) |
# +-----------------+---------------+--------------------------+---------------------------+
# |      teste1     |     junta     |          14.63           |           19.51           |
# |      teste2     |     junta     |           16.6           |           19.51           |
# |      teste3     |     junta     |          11.03           |           19.51           |
# |      teste4     |     junta     |           12.1           |           19.51           |
# |      teste5     |     junta     |          10.67           |           19.51           |
# |      teste6     |     junta     |           10.6           |           19.39           |
# |      teste7     |     junta     |           9.87           |           19.38           |
# |      teste8     |     junta     |           10.7           |           18.83           |
# |      teste9     |     junta     |           10.2           |            19.2           |
# |     teste10     |     junta     |           9.6            |           19.13           |
# |     teste11     |     junta     |           9.5            |           19.19           |
# |     teste12     |     junta     |           9.23           |           19.47           |
# |     teste13     |     junta     |           8.77           |           19.15           |
# |     teste14     |     junta     |          10.17           |           18.69           |
# |     teste15     |     junta     |           9.4            |           18.82           |
# |     teste16     |     junta     |           9.33           |           18.34           |
# |     teste17     |     junta     |           9.63           |           18.65           |
# |     teste18     |     junta     |          155.6           |           19.35           |
# |     teste19     |     junta     |          141.07          |           18.55           |
# |     teste20     |     junta     |          85.37           |           18.88           |
# |     teste21     |     junta     |           8.83           |           18.72           |
# |     teste22     |     junta     |           8.0            |           18.45           |
# |     teste23     |     junta     |           9.4            |           17.96           |
# |     teste24     |     junta     |          152.33          |            18.6           |
# |     teste25     |     junta     |           94.4           |            18.6           |
# |     teste26     |     junta     |           9.27           |           18.79           |
# |     teste27     |     junta     |           9.87           |           18.61           |
# |     teste28     |     junta     |           8.13           |           18.62           |
# |     teste29     |     junta     |           9.3            |           19.31           |
# |     teste30     |     junta     |           8.73           |           19.26           |
# |     teste31     |     junta     |           8.37           |           18.73           |
# |     teste32     |     junta     |           8.07           |           18.57           |
# |     teste33     |     junta     |           8.17           |           19.14           |
# |     teste34     |     junta     |           70.1           |           19.31           |
# |     teste35     |     junta     |           9.43           |           18.72           |
# |     teste36     |     junta     |           11.2           |           18.92           |
# |     teste37     |     junta     |          10.27           |           19.16           |
# |     teste38     |     junta     |           9.1            |           18.95           |
# |     teste39     |     junta     |          12.23           |           18.41           |
# |     teste40     |     junta     |          10.03           |           18.41           |
# |     teste41     |     junta     |           9.03           |           18.49           |
# |     teste42     |     junta     |           8.97           |           18.85           |
# |     teste43     |     junta     |           9.57           |           18.64           |
# |     teste44     |     junta     |           8.4            |           18.84           |
# |     teste45     |     junta     |           9.03           |           18.66           |
# |     teste46     |     junta     |           10.3           |           19.02           |
# |     teste47     |     junta     |           8.9            |           19.25           |
# |     teste48     |     junta     |          10.13           |           19.05           |
# +-----------------+---------------+--------------------------+---------------------------+

# %%
classLabels = ["cracking","junta","Solda", "squat"]
caminho_figuras =  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta'
caminho_modelo = '/content/drive/My Drive/Projeto Eddy Current/ProjetoFinal/modelo/4classes100Ev2.hdf5'
############### Faz a classificação das categorias  ################
### Cria Operador Modelo CNN
Operador_cnn=modelo_cnn()
### Faz a Classificação dos Sinais 
Operador_cnn.classifica_sinais (classLabels,caminho_figuras,caminho_modelo)
# Out:
# [INFO] sampling images...
# ImagePaths:  ['/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/676.jpg'
#  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/677.jpg'
#  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/678.jpg'
#  ...
#  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/213.jpg'
#  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/214.jpg'
#  '/content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/215.jpg']
# idxs:  [   0    1    2 ... 1131 1132 1134]
# [INFO] loading pre-trained network...
# [INFO] predicting...
# Classes : [1 1 1 ... 1 1 1]
# Labels ['Junta' 'Junta' 'Junta' ... 'Junta' 'Junta' 'Junta']
# Classe:  junta
#  Nome do Arquivo:  676
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/676.jpg
# Classe:  junta
#  Nome do Arquivo:  677
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/677.jpg
# Classe:  junta
#  Nome do Arquivo:  678
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/678.jpg
# Classe:  junta
#  Nome do Arquivo:  679
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/679.jpg
# Classe:  junta
#  Nome do Arquivo:  680
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/680.jpg
# Classe:  junta
#  Nome do Arquivo:  681
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/681.jpg
# Classe:  junta
#  Nome do Arquivo:  682
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/682.jpg
# Classe:  junta
#  Nome do Arquivo:  683
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/683.jpg
# Classe:  junta
#  Nome do Arquivo:  684
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/684.jpg
# Classe:  junta
#  Nome do Arquivo:  685
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/685.jpg
# Classe:  junta
#  Nome do Arquivo:  686
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/686.jpg
# Classe:  junta
#  Nome do Arquivo:  687
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/687.jpg
# Classe:  junta
#  Nome do Arquivo:  688
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/688.jpg
# Classe:  junta
#  Nome do Arquivo:  689
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/689.jpg
# Classe:  junta
#  Nome do Arquivo:  690
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/690.jpg
# Classe:  junta
#  Nome do Arquivo:  691
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/691.jpg
# Classe:  junta
#  Nome do Arquivo:  692
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/692.jpg
# Classe:  junta
#  Nome do Arquivo:  693
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/693.jpg
# Classe:  junta
#  Nome do Arquivo:  694
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/694.jpg
# Classe:  junta
#  Nome do Arquivo:  695
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/695.jpg
# Classe:  junta
#  Nome do Arquivo:  696
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/696.jpg
# Classe:  junta
#  Nome do Arquivo:  697
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/697.jpg
# Classe:  junta
#  Nome do Arquivo:  698
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/698.jpg
# Classe:  junta
#  Nome do Arquivo:  699
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/699.jpg
# Classe:  junta
#  Nome do Arquivo:  700
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/700.jpg
# Classe:  junta
#  Nome do Arquivo:  701
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/701.jpg
# Classe:  junta
#  Nome do Arquivo:  702
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/702.jpg
# Classe:  junta
#  Nome do Arquivo:  703
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/703.jpg
# Classe:  junta
#  Nome do Arquivo:  704
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/704.jpg
# Classe:  junta
#  Nome do Arquivo:  705
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/705.jpg
# Classe:  junta
#  Nome do Arquivo:  706
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/706.jpg
# Classe:  junta
#  Nome do Arquivo:  707
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/707.jpg
# Classe:  junta
#  Nome do Arquivo:  708
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/708.jpg
# Classe:  junta
#  Nome do Arquivo:  709
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/709.jpg
# Classe:  junta
#  Nome do Arquivo:  710
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/710.jpg
# Classe:  junta
#  Nome do Arquivo:  711
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/711.jpg
# Classe:  junta
#  Nome do Arquivo:  712
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/712.jpg
# Classe:  junta
#  Nome do Arquivo:  713
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/713.jpg
# Classe:  junta
#  Nome do Arquivo:  714
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/714.jpg
# Classe:  junta
#  Nome do Arquivo:  715
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/715.jpg
# Classe:  junta
#  Nome do Arquivo:  716
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/716.jpg
# Classe:  junta
#  Nome do Arquivo:  717
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/717.jpg
# Classe:  junta
#  Nome do Arquivo:  718
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/718.jpg
# Classe:  junta
#  Nome do Arquivo:  719
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/719.jpg
# Classe:  junta
#  Nome do Arquivo:  720
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/720.jpg
# Classe:  junta
#  Nome do Arquivo:  721
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/721.jpg
# Classe:  junta
#  Nome do Arquivo:  722
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/722.jpg
# Classe:  junta
#  Nome do Arquivo:  723
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/723.jpg
# Classe:  junta
#  Nome do Arquivo:  724
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/724.jpg
# Classe:  junta
#  Nome do Arquivo:  725
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/725.jpg
# Classe:  junta
#  Nome do Arquivo:  726
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/726.jpg
# Classe:  junta
#  Nome do Arquivo:  727
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/727.jpg
# Classe:  junta
#  Nome do Arquivo:  728
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/728.jpg
# Classe:  junta
#  Nome do Arquivo:  729
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/729.jpg
# Classe:  junta
#  Nome do Arquivo:  730
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/730.jpg
# Classe:  junta
#  Nome do Arquivo:  731
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/731.jpg
# Classe:  junta
#  Nome do Arquivo:  732
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/732.jpg
# Classe:  junta
#  Nome do Arquivo:  733
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/733.jpg
# Classe:  junta
#  Nome do Arquivo:  734
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/734.jpg
# Classe:  junta
#  Nome do Arquivo:  735
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/735.jpg
# Classe:  junta
#  Nome do Arquivo:  736
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/736.jpg
# Classe:  junta
#  Nome do Arquivo:  737
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/737.jpg
# Classe:  junta
#  Nome do Arquivo:  738
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/738.jpg
# Classe:  junta
#  Nome do Arquivo:  739
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/739.jpg
# Classe:  junta
#  Nome do Arquivo:  740
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/740.jpg
# Classe:  junta
#  Nome do Arquivo:  741
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/741.jpg
# Classe:  junta
#  Nome do Arquivo:  742
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/742.jpg
# Classe:  junta
#  Nome do Arquivo:  743
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/743.jpg
# Classe:  junta
#  Nome do Arquivo:  744
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/744.jpg
# Classe:  junta
#  Nome do Arquivo:  745
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/745.jpg
# Classe:  junta
#  Nome do Arquivo:  746
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/746.jpg
# Classe:  junta
#  Nome do Arquivo:  747
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/747.jpg
# Classe:  junta
#  Nome do Arquivo:  748
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/748.jpg
# Classe:  junta
#  Nome do Arquivo:  749
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/749.jpg
# Classe:  junta
#  Nome do Arquivo:  750
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/750.jpg
# Classe:  junta
#  Nome do Arquivo:  751
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/751.jpg
# Classe:  junta
#  Nome do Arquivo:  752
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/752.jpg
# Classe:  junta
#  Nome do Arquivo:  753
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/753.jpg
# Classe:  junta
#  Nome do Arquivo:  754
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/754.jpg
# Classe:  junta
#  Nome do Arquivo:  755
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/755.jpg
# Classe:  junta
#  Nome do Arquivo:  756
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/756.jpg
# Classe:  junta
#  Nome do Arquivo:  757
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/757.jpg
# Classe:  junta
#  Nome do Arquivo:  758
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/758.jpg
# Classe:  junta
#  Nome do Arquivo:  759
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/759.jpg
# Classe:  junta
#  Nome do Arquivo:  760
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/760.jpg
# Classe:  junta
#  Nome do Arquivo:  761
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/761.jpg
# Classe:  junta
#  Nome do Arquivo:  762
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/762.jpg
# Classe:  junta
#  Nome do Arquivo:  763
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/763.jpg
# Classe:  junta
#  Nome do Arquivo:  764
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/764.jpg
# Classe:  junta
#  Nome do Arquivo:  765
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/765.jpg
# Classe:  junta
#  Nome do Arquivo:  766
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/766.jpg
# Classe:  junta
#  Nome do Arquivo:  767
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/767.jpg
# Classe:  junta
#  Nome do Arquivo:  768
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/768.jpg
# Classe:  junta
#  Nome do Arquivo:  769
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/769.jpg
# Classe:  junta
#  Nome do Arquivo:  770
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/770.jpg
# Classe:  junta
#  Nome do Arquivo:  771
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/771.jpg
# Classe:  junta
#  Nome do Arquivo:  772
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/772.jpg
# Classe:  junta
#  Nome do Arquivo:  773
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/773.jpg
# Classe:  junta
#  Nome do Arquivo:  774
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/774.jpg
# Classe:  junta
#  Nome do Arquivo:  775
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/775.jpg
# Classe:  junta
#  Nome do Arquivo:  776
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/776.jpg
# Classe:  junta
#  Nome do Arquivo:  777
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/777.jpg
# Classe:  junta
#  Nome do Arquivo:  778
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/778.jpg
# Classe:  junta
#  Nome do Arquivo:  779
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/779.jpg
# Classe:  junta
#  Nome do Arquivo:  780
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/780.jpg
# Classe:  junta
#  Nome do Arquivo:  781
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/781.jpg
# Classe:  junta
#  Nome do Arquivo:  782
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/782.jpg
# Classe:  junta
#  Nome do Arquivo:  783
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/783.jpg
# Classe:  junta
#  Nome do Arquivo:  784
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/784.jpg
# Classe:  junta
#  Nome do Arquivo:  785
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/785.jpg
# Classe:  junta
#  Nome do Arquivo:  786
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/786.jpg
# Classe:  junta
#  Nome do Arquivo:  787
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/787.jpg
# Classe:  junta
#  Nome do Arquivo:  788
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/788.jpg
# Classe:  junta
#  Nome do Arquivo:  789
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/789.jpg
# Classe:  junta
#  Nome do Arquivo:  790
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/790.jpg
# Classe:  junta
#  Nome do Arquivo:  791
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/791.jpg
# Classe:  junta
#  Nome do Arquivo:  792
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/792.jpg
# Classe:  junta
#  Nome do Arquivo:  793
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/793.jpg
# Classe:  squat
#  Nome do Arquivo:  794
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/794.jpg
# Classe:  junta
#  Nome do Arquivo:  795
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/795.jpg
# Classe:  junta
#  Nome do Arquivo:  796
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/796.jpg
# Classe:  junta
#  Nome do Arquivo:  797
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/797.jpg
# Classe:  junta
#  Nome do Arquivo:  798
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/798.jpg
# Classe:  junta
#  Nome do Arquivo:  799
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/799.jpg
# Classe:  junta
#  Nome do Arquivo:  800
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/800.jpg
# Classe:  junta
#  Nome do Arquivo:  801
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/801.jpg
# Classe:  junta
#  Nome do Arquivo:  802
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/802.jpg
# Classe:  junta
#  Nome do Arquivo:  803
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/803.jpg
# Classe:  junta
#  Nome do Arquivo:  804
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/804.jpg
# Classe:  junta
#  Nome do Arquivo:  805
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/805.jpg
# Classe:  junta
#  Nome do Arquivo:  806
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/806.jpg
# Classe:  junta
#  Nome do Arquivo:  807
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/807.jpg
# Classe:  squat
#  Nome do Arquivo:  808
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/808.jpg
# Classe:  junta
#  Nome do Arquivo:  809
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/809.jpg
# Classe:  junta
#  Nome do Arquivo:  810
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/810.jpg
# Classe:  squat
#  Nome do Arquivo:  811
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/811.jpg
# Classe:  junta
#  Nome do Arquivo:  812
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/812.jpg
# Classe:  junta
#  Nome do Arquivo:  813
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/813.jpg
# Classe:  squat
#  Nome do Arquivo:  814
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/814.jpg
# Classe:  junta
#  Nome do Arquivo:  815
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/815.jpg
# Classe:  junta
#  Nome do Arquivo:  816
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/816.jpg
# Classe:  junta
#  Nome do Arquivo:  817
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/817.jpg
# Classe:  junta
#  Nome do Arquivo:  818
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/818.jpg
# Classe:  junta
#  Nome do Arquivo:  819
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/819.jpg
# Classe:  junta
#  Nome do Arquivo:  820
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/820.jpg
# Classe:  junta
#  Nome do Arquivo:  821
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/821.jpg
# Classe:  junta
#  Nome do Arquivo:  822
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/822.jpg
# Classe:  squat
#  Nome do Arquivo:  823
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/823.jpg
# Classe:  junta
#  Nome do Arquivo:  824
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/824.jpg
# Classe:  junta
#  Nome do Arquivo:  825
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/825.jpg
# Classe:  junta
#  Nome do Arquivo:  826
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/826.jpg
# Classe:  junta
#  Nome do Arquivo:  827
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/827.jpg
# Classe:  junta
#  Nome do Arquivo:  828
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/828.jpg
# Classe:  junta
#  Nome do Arquivo:  829
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/829.jpg
# Classe:  junta
#  Nome do Arquivo:  830
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/830.jpg
# Classe:  junta
#  Nome do Arquivo:  831
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/831.jpg
# Classe:  junta
#  Nome do Arquivo:  832
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/832.jpg
# Classe:  junta
#  Nome do Arquivo:  833
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/833.jpg
# Classe:  junta
#  Nome do Arquivo:  834
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/834.jpg
# Classe:  junta
#  Nome do Arquivo:  835
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/835.jpg
# Classe:  junta
#  Nome do Arquivo:  836
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/836.jpg
# Classe:  junta
#  Nome do Arquivo:  837
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/837.jpg
# Classe:  junta
#  Nome do Arquivo:  838
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/838.jpg
# Classe:  junta
#  Nome do Arquivo:  839
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/839.jpg
# Classe:  junta
#  Nome do Arquivo:  840
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/840.jpg
# Classe:  solda
#  Nome do Arquivo:  841
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/841.jpg
# Classe:  junta
#  Nome do Arquivo:  842
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/842.jpg
# Classe:  junta
#  Nome do Arquivo:  843
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/843.jpg
# Classe:  junta
#  Nome do Arquivo:  844
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/844.jpg
# Classe:  junta
#  Nome do Arquivo:  845
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/845.jpg
# Classe:  solda
#  Nome do Arquivo:  846
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/846.jpg
# Classe:  junta
#  Nome do Arquivo:  847
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/847.jpg
# Classe:  squat
#  Nome do Arquivo:  848
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/848.jpg
# Classe:  junta
#  Nome do Arquivo:  849
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/849.jpg
# Classe:  solda
#  Nome do Arquivo:  850
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/850.jpg
# Classe:  junta
#  Nome do Arquivo:  851
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/851.jpg
# Classe:  junta
#  Nome do Arquivo:  852
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/852.jpg
# Classe:  solda
#  Nome do Arquivo:  853
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/853.jpg
# Classe:  junta
#  Nome do Arquivo:  854
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/854.jpg
# Classe:  squat
#  Nome do Arquivo:  855
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/855.jpg
# Classe:  junta
#  Nome do Arquivo:  856
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/856.jpg
# Classe:  junta
#  Nome do Arquivo:  857
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/857.jpg
# Classe:  junta
#  Nome do Arquivo:  858
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/858.jpg
# Classe:  junta
#  Nome do Arquivo:  859
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/859.jpg
# Classe:  junta
#  Nome do Arquivo:  860
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/860.jpg
# Classe:  junta
#  Nome do Arquivo:  861
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/861.jpg
# Classe:  junta
#  Nome do Arquivo:  862
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/862.jpg
# Classe:  junta
#  Nome do Arquivo:  863
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/863.jpg
# Classe:  junta
#  Nome do Arquivo:  864
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/864.jpg
# Classe:  junta
#  Nome do Arquivo:  865
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/865.jpg
# Classe:  junta
#  Nome do Arquivo:  866
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/866.jpg
# Classe:  junta
#  Nome do Arquivo:  867
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/867.jpg
# Classe:  junta
#  Nome do Arquivo:  868
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/868.jpg
# Classe:  junta
#  Nome do Arquivo:  869
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/869.jpg
# Classe:  junta
#  Nome do Arquivo:  870
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/870.jpg
# Classe:  junta
#  Nome do Arquivo:  871
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/871.jpg
# Classe:  junta
#  Nome do Arquivo:  872
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/872.jpg
# Classe:  junta
#  Nome do Arquivo:  873
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/873.jpg
# Classe:  junta
#  Nome do Arquivo:  874
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/874.jpg
# Classe:  junta
#  Nome do Arquivo:  875
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/875.jpg
# Classe:  junta
#  Nome do Arquivo:  876
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/876.jpg
# Classe:  junta
#  Nome do Arquivo:  877
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/877.jpg
# Classe:  junta
#  Nome do Arquivo:  878
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/878.jpg
# Classe:  junta
#  Nome do Arquivo:  879
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/879.jpg
# Classe:  junta
#  Nome do Arquivo:  880
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/880.jpg
# Classe:  junta
#  Nome do Arquivo:  881
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/881.jpg
# Classe:  junta
#  Nome do Arquivo:  882
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/882.jpg
# Classe:  junta
#  Nome do Arquivo:  883
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/883.jpg
# Classe:  junta
#  Nome do Arquivo:  884
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/884.jpg
# Classe:  junta
#  Nome do Arquivo:  885
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/885.jpg
# Classe:  junta
#  Nome do Arquivo:  886
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/886.jpg
# Classe:  junta
#  Nome do Arquivo:  887
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/887.jpg
# Classe:  junta
#  Nome do Arquivo:  888
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/888.jpg
# Classe:  junta
#  Nome do Arquivo:  889
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/889.jpg
# Classe:  junta
#  Nome do Arquivo:  890
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/890.jpg
# Classe:  junta
#  Nome do Arquivo:  891
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/891.jpg
# Classe:  junta
#  Nome do Arquivo:  892
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/892.jpg
# Classe:  junta
#  Nome do Arquivo:  893
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/893.jpg
# Classe:  junta
#  Nome do Arquivo:  894
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/894.jpg
# Classe:  junta
#  Nome do Arquivo:  895
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/895.jpg
# Classe:  junta
#  Nome do Arquivo:  896
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/896.jpg
# Classe:  junta
#  Nome do Arquivo:  897
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/897.jpg
# Classe:  junta
#  Nome do Arquivo:  898
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/898.jpg
# Classe:  junta
#  Nome do Arquivo:  899
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/899.jpg
# Classe:  junta
#  Nome do Arquivo:  900
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/900.jpg
# Classe:  junta
#  Nome do Arquivo:  901
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/901.jpg
# Classe:  junta
#  Nome do Arquivo:  902
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/902.jpg
# Classe:  junta
#  Nome do Arquivo:  903
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/903.jpg
# Classe:  junta
#  Nome do Arquivo:  904
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/904.jpg
# Classe:  junta
#  Nome do Arquivo:  905
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/905.jpg
# Classe:  junta
#  Nome do Arquivo:  906
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/906.jpg
# Classe:  junta
#  Nome do Arquivo:  907
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/907.jpg
# Classe:  junta
#  Nome do Arquivo:  908
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/908.jpg
# Classe:  junta
#  Nome do Arquivo:  909
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/909.jpg
# Classe:  junta
#  Nome do Arquivo:  910
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/910.jpg
# Classe:  junta
#  Nome do Arquivo:  911
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/911.jpg
# Classe:  junta
#  Nome do Arquivo:  912
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/912.jpg
# Classe:  junta
#  Nome do Arquivo:  913
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/913.jpg
# Classe:  junta
#  Nome do Arquivo:  914
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/914.jpg
# Classe:  junta
#  Nome do Arquivo:  915
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/915.jpg
# Classe:  junta
#  Nome do Arquivo:  916
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/916.jpg
# Classe:  junta
#  Nome do Arquivo:  917
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/917.jpg
# Classe:  junta
#  Nome do Arquivo:  918
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/918.jpg
# Classe:  junta
#  Nome do Arquivo:  919
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/919.jpg
# Classe:  junta
#  Nome do Arquivo:  920
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/920.jpg
# Classe:  junta
#  Nome do Arquivo:  921
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/921.jpg
# Classe:  junta
#  Nome do Arquivo:  922
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/922.jpg
# Classe:  junta
#  Nome do Arquivo:  923
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/923.jpg
# Classe:  junta
#  Nome do Arquivo:  924
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/924.jpg
# Classe:  junta
#  Nome do Arquivo:  925
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/925.jpg
# Classe:  junta
#  Nome do Arquivo:  926
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/926.jpg
# Classe:  junta
#  Nome do Arquivo:  927
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/927.jpg
# Classe:  junta
#  Nome do Arquivo:  928
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/928.jpg
# Classe:  junta
#  Nome do Arquivo:  929
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/929.jpg
# Classe:  junta
#  Nome do Arquivo:  930
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/930.jpg
# Classe:  junta
#  Nome do Arquivo:  931
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/931.jpg
# Classe:  junta
#  Nome do Arquivo:  932
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/932.jpg
# Classe:  junta
#  Nome do Arquivo:  933
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/933.jpg
# Classe:  squat
#  Nome do Arquivo:  934
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/934.jpg
# Classe:  junta
#  Nome do Arquivo:  935
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/935.jpg
# Classe:  junta
#  Nome do Arquivo:  936
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/936.jpg
# Classe:  junta
#  Nome do Arquivo:  937
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/937.jpg
# Classe:  junta
#  Nome do Arquivo:  938
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/938.jpg
# Classe:  junta
#  Nome do Arquivo:  939
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/939.jpg
# Classe:  junta
#  Nome do Arquivo:  940
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/940.jpg
# Classe:  junta
#  Nome do Arquivo:  941
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/941.jpg
# Classe:  junta
#  Nome do Arquivo:  942
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/942.jpg
# Classe:  junta
#  Nome do Arquivo:  943
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/943.jpg
# Classe:  junta
#  Nome do Arquivo:  944
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/944.jpg
# Classe:  junta
#  Nome do Arquivo:  945
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/945.jpg
# Classe:  junta
#  Nome do Arquivo:  946
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/946.jpg
# Classe:  junta
#  Nome do Arquivo:  947
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/947.jpg
# Classe:  junta
#  Nome do Arquivo:  948
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/948.jpg
# Classe:  junta
#  Nome do Arquivo:  949
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/949.jpg
# Classe:  junta
#  Nome do Arquivo:  950
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/950.jpg
# Classe:  junta
#  Nome do Arquivo:  951
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/951.jpg
# Classe:  junta
#  Nome do Arquivo:  952
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/952.jpg
# Classe:  junta
#  Nome do Arquivo:  953
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/953.jpg
# Classe:  junta
#  Nome do Arquivo:  954
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/954.jpg
# Classe:  junta
#  Nome do Arquivo:  955
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/955.jpg
# Classe:  junta
#  Nome do Arquivo:  956
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/956.jpg
# Classe:  junta
#  Nome do Arquivo:  957
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/957.jpg
# Classe:  junta
#  Nome do Arquivo:  958
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/958.jpg
# Classe:  junta
#  Nome do Arquivo:  959
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/959.jpg
# Classe:  junta
#  Nome do Arquivo:  960
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/960.jpg
# Classe:  junta
#  Nome do Arquivo:  961
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/961.jpg
# Classe:  junta
#  Nome do Arquivo:  962
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/962.jpg
# Classe:  junta
#  Nome do Arquivo:  963
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/963.jpg
# Classe:  junta
#  Nome do Arquivo:  964
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/964.jpg
# Classe:  junta
#  Nome do Arquivo:  965
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/965.jpg
# Classe:  junta
#  Nome do Arquivo:  966
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/966.jpg
# Classe:  junta
#  Nome do Arquivo:  967
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/967.jpg
# Classe:  junta
#  Nome do Arquivo:  968
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/968.jpg
# Classe:  junta
#  Nome do Arquivo:  969
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/969.jpg
# Classe:  solda
#  Nome do Arquivo:  970
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/970.jpg
# Classe:  solda
#  Nome do Arquivo:  971
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/971.jpg
# Classe:  junta
#  Nome do Arquivo:  972
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/972.jpg
# Classe:  junta
#  Nome do Arquivo:  973
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/973.jpg
# Classe:  junta
#  Nome do Arquivo:  974
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/974.jpg
# Classe:  junta
#  Nome do Arquivo:  975
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/975.jpg
# Classe:  solda
#  Nome do Arquivo:  976
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/976.jpg
# Classe:  junta
#  Nome do Arquivo:  977
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/977.jpg
# Classe:  junta
#  Nome do Arquivo:  978
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/978.jpg
# Classe:  junta
#  Nome do Arquivo:  979
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/979.jpg
# Classe:  junta
#  Nome do Arquivo:  980
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/980.jpg
# Classe:  solda
#  Nome do Arquivo:  981
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/981.jpg
# Classe:  solda
#  Nome do Arquivo:  982
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/982.jpg
# Classe:  solda
#  Nome do Arquivo:  983
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/983.jpg
# Classe:  solda
#  Nome do Arquivo:  984
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/984.jpg
# Classe:  solda
#  Nome do Arquivo:  985
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/985.jpg
# Classe:  solda
#  Nome do Arquivo:  986
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/986.jpg
# Classe:  squat
#  Nome do Arquivo:  987
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/987.jpg
# Classe:  solda
#  Nome do Arquivo:  988
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/988.jpg
# Classe:  squat
#  Nome do Arquivo:  989
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/989.jpg
# Classe:  solda
#  Nome do Arquivo:  990
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/990.jpg
# Classe:  solda
#  Nome do Arquivo:  991
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/991.jpg
# Classe:  solda
#  Nome do Arquivo:  992
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/992.jpg
# Classe:  solda
#  Nome do Arquivo:  993
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/993.jpg
# Classe:  solda
#  Nome do Arquivo:  994
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/994.jpg
# Classe:  squat
#  Nome do Arquivo:  995
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/995.jpg
# Classe:  solda
#  Nome do Arquivo:  996
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/996.jpg
# Classe:  solda
#  Nome do Arquivo:  997
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/997.jpg
# Classe:  solda
#  Nome do Arquivo:  998
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/998.jpg
# Classe:  solda
#  Nome do Arquivo:  999
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/999.jpg
# Classe:  solda
#  Nome do Arquivo:  1000
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1000.jpg
# Classe:  solda
#  Nome do Arquivo:  1001
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1001.jpg
# Classe:  squat
#  Nome do Arquivo:  1002
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1002.jpg
# Classe:  solda
#  Nome do Arquivo:  1003
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1003.jpg
# Classe:  solda
#  Nome do Arquivo:  1004
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1004.jpg
# Classe:  solda
#  Nome do Arquivo:  1005
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1005.jpg
# Classe:  junta
#  Nome do Arquivo:  1006
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1006.jpg
# Classe:  junta
#  Nome do Arquivo:  1007
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1007.jpg
# Classe:  junta
#  Nome do Arquivo:  1008
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1008.jpg
# Classe:  junta
#  Nome do Arquivo:  1009
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1009.jpg
# Classe:  junta
#  Nome do Arquivo:  1010
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1010.jpg
# Classe:  junta
#  Nome do Arquivo:  1011
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1011.jpg
# Classe:  junta
#  Nome do Arquivo:  1012
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1012.jpg
# Classe:  junta
#  Nome do Arquivo:  1013
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1013.jpg
# Classe:  junta
#  Nome do Arquivo:  1014
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1014.jpg
# Classe:  junta
#  Nome do Arquivo:  1015
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1015.jpg
# Classe:  junta
#  Nome do Arquivo:  1016
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/1016.jpg
# Classe:  junta
#  Nome do Arquivo:  1017
# ...
#  Nome do Arquivo:  99
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/99.jpg
# Classe:  junta
#  Nome do Arquivo:  100
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/100.jpg
# Classe:  junta
#  Nome do Arquivo:  101
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/101.jpg
# Classe:  junta
#  Nome do Arquivo:  102
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/102.jpg
# Classe:  junta
#  Nome do Arquivo:  103
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/103.jpg
# Classe:  junta
#  Nome do Arquivo:  104
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/104.jpg
# Classe:  junta
#  Nome do Arquivo:  105
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/105.jpg
# Classe:  junta
#  Nome do Arquivo:  106
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/106.jpg
# Classe:  junta
#  Nome do Arquivo:  107
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/107.jpg
# Classe:  junta
#  Nome do Arquivo:  108
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/108.jpg
# Classe:  junta
#  Nome do Arquivo:  109
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/109.jpg
# Classe:  junta
#  Nome do Arquivo:  110
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/110.jpg
# Classe:  junta
#  Nome do Arquivo:  111
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/111.jpg
# Classe:  junta
#  Nome do Arquivo:  112
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/112.jpg
# Classe:  junta
#  Nome do Arquivo:  113
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/113.jpg
# Classe:  junta
#  Nome do Arquivo:  114
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/114.jpg
# Classe:  junta
#  Nome do Arquivo:  115
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/115.jpg
# Classe:  junta
#  Nome do Arquivo:  116
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/116.jpg
# Classe:  junta
#  Nome do Arquivo:  117
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/117.jpg
# Classe:  junta
#  Nome do Arquivo:  118
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/118.jpg
# Classe:  junta
#  Nome do Arquivo:  119
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/119.jpg
# Classe:  junta
#  Nome do Arquivo:  120
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/120.jpg
# Classe:  junta
#  Nome do Arquivo:  121
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/121.jpg
# Classe:  junta
#  Nome do Arquivo:  122
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/122.jpg
# Classe:  junta
#  Nome do Arquivo:  123
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/123.jpg
# Classe:  junta
#  Nome do Arquivo:  124
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/124.jpg
# Classe:  junta
#  Nome do Arquivo:  125
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/125.jpg
# Classe:  junta
#  Nome do Arquivo:  126
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/126.jpg
# Classe:  junta
#  Nome do Arquivo:  127
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/127.jpg
# Classe:  junta
#  Nome do Arquivo:  128
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/128.jpg
# Classe:  junta
#  Nome do Arquivo:  129
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/129.jpg
# Classe:  junta
#  Nome do Arquivo:  130
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/130.jpg
# Classe:  junta
#  Nome do Arquivo:  131
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/131.jpg
# Classe:  junta
#  Nome do Arquivo:  132
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/132.jpg
# Classe:  junta
#  Nome do Arquivo:  133
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/133.jpg
# Classe:  junta
#  Nome do Arquivo:  134
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/134.jpg
# Classe:  junta
#  Nome do Arquivo:  135
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/135.jpg
# Classe:  junta
#  Nome do Arquivo:  136
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/136.jpg
# Classe:  junta
#  Nome do Arquivo:  137
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/137.jpg
# Classe:  junta
#  Nome do Arquivo:  138
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/138.jpg
# Classe:  junta
#  Nome do Arquivo:  139
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/139.jpg
# Classe:  junta
#  Nome do Arquivo:  140
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/140.jpg
# Classe:  junta
#  Nome do Arquivo:  141
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/141.jpg
# Classe:  junta
#  Nome do Arquivo:  142
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/142.jpg
# Classe:  junta
#  Nome do Arquivo:  143
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/143.jpg
# Classe:  junta
#  Nome do Arquivo:  144
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/144.jpg
# Classe:  junta
#  Nome do Arquivo:  145
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/145.jpg
# Classe:  junta
#  Nome do Arquivo:  146
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/146.jpg
# Classe:  junta
#  Nome do Arquivo:  147
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/147.jpg
# Classe:  junta
#  Nome do Arquivo:  148
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/148.jpg
# Classe:  junta
#  Nome do Arquivo:  149
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/149.jpg
# Classe:  junta
#  Nome do Arquivo:  150
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/150.jpg
# Classe:  junta
#  Nome do Arquivo:  151
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/151.jpg
# Classe:  junta
#  Nome do Arquivo:  152
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/152.jpg
# Classe:  junta
#  Nome do Arquivo:  153
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/153.jpg
# Classe:  junta
#  Nome do Arquivo:  154
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/154.jpg
# Classe:  junta
#  Nome do Arquivo:  155
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/155.jpg
# Classe:  junta
#  Nome do Arquivo:  156
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/156.jpg
# Classe:  junta
#  Nome do Arquivo:  157
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/157.jpg
# Classe:  junta
#  Nome do Arquivo:  158
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/158.jpg
# Classe:  junta
#  Nome do Arquivo:  159
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/159.jpg
# Classe:  squat
#  Nome do Arquivo:  160
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/160.jpg
# Classe:  solda
#  Nome do Arquivo:  161
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/161.jpg
# Classe:  junta
#  Nome do Arquivo:  162
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/162.jpg
# Classe:  junta
#  Nome do Arquivo:  163
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/163.jpg
# Classe:  junta
#  Nome do Arquivo:  164
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/164.jpg
# Classe:  solda
#  Nome do Arquivo:  165
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/165.jpg
# Classe:  squat
#  Nome do Arquivo:  166
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/166.jpg
# Classe:  squat
#  Nome do Arquivo:  167
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/167.jpg
# Classe:  squat
#  Nome do Arquivo:  168
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/168.jpg
# Classe:  junta
#  Nome do Arquivo:  169
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/169.jpg
# Classe:  squat
#  Nome do Arquivo:  170
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/170.jpg
# Classe:  junta
#  Nome do Arquivo:  171
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/171.jpg
# Classe:  squat
#  Nome do Arquivo:  172
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/172.jpg
# Classe:  junta
#  Nome do Arquivo:  173
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/173.jpg
# Classe:  squat
#  Nome do Arquivo:  174
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/174.jpg
# Classe:  junta
#  Nome do Arquivo:  175
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/175.jpg
# Classe:  junta
#  Nome do Arquivo:  176
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/176.jpg
# Classe:  junta
#  Nome do Arquivo:  177
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/177.jpg
# Classe:  junta
#  Nome do Arquivo:  178
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/178.jpg
# Classe:  junta
#  Nome do Arquivo:  179
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/179.jpg
# Classe:  junta
#  Nome do Arquivo:  180
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/180.jpg
# Classe:  junta
#  Nome do Arquivo:  181
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/181.jpg
# Classe:  junta
#  Nome do Arquivo:  182
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/182.jpg
# Classe:  junta
#  Nome do Arquivo:  183
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/183.jpg
# Classe:  junta
#  Nome do Arquivo:  184
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/184.jpg
# Classe:  junta
#  Nome do Arquivo:  185
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/185.jpg
# Classe:  junta
#  Nome do Arquivo:  186
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/186.jpg
# Classe:  junta
#  Nome do Arquivo:  187
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/187.jpg
# Classe:  junta
#  Nome do Arquivo:  188
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/188.jpg
# Classe:  junta
#  Nome do Arquivo:  189
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/189.jpg
# Classe:  junta
#  Nome do Arquivo:  190
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/190.jpg
# Classe:  junta
#  Nome do Arquivo:  191
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/191.jpg
# Classe:  junta
#  Nome do Arquivo:  192
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/192.jpg
# Classe:  junta
#  Nome do Arquivo:  193
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/193.jpg
# Classe:  junta
#  Nome do Arquivo:  194
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/194.jpg
# Classe:  junta
#  Nome do Arquivo:  195
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/195.jpg
# Classe:  junta
#  Nome do Arquivo:  196
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/196.jpg
# Classe:  junta
#  Nome do Arquivo:  197
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/197.jpg
# Classe:  junta
#  Nome do Arquivo:  198
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/198.jpg
# Classe:  junta
#  Nome do Arquivo:  199
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/199.jpg
# Classe:  junta
#  Nome do Arquivo:  200
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/200.jpg
# Classe:  junta
#  Nome do Arquivo:  201
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/201.jpg
# Classe:  junta
#  Nome do Arquivo:  202
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/202.jpg
# Classe:  junta
#  Nome do Arquivo:  203
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/203.jpg
# Classe:  junta
#  Nome do Arquivo:  204
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/204.jpg
# Classe:  junta
#  Nome do Arquivo:  205
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/205.jpg
# Classe:  junta
#  Nome do Arquivo:  206
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/206.jpg
# Classe:  junta
#  Nome do Arquivo:  207
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/207.jpg
# Classe:  junta
#  Nome do Arquivo:  208
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/208.jpg
# Classe:  junta
#  Nome do Arquivo:  209
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/209.jpg
# Classe:  junta
#  Nome do Arquivo:  210
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/210.jpg
# Classe:  junta
#  Nome do Arquivo:  211
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/211.jpg
# Classe:  junta
#  Nome do Arquivo:  212
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/212.jpg
# Classe:  junta
#  Nome do Arquivo:  213
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/213.jpg
# Classe:  junta
#  Nome do Arquivo:  215
# /content/drive/My Drive/Projeto Eddy Current/Supervisionado/Figuras_Python_CNN/train2/Junta/215.jpg

# %%
from prettytable import PrettyTable
from prettytable import from_csv
from prettytable import from_html

# Cria a tabela
x = PrettyTable(["Nome do Arquivo", "Classificação", "Comprimento"])

# Alinha as colunas
x.align["Nome do Arquivo"] = "l"
x.align["Classificação"] = "l"
x.align["Comprimento"] = "r"
#x.align["Latitude"] = "r"
#x.align["Longitude"] = "r"

# Deixa um espaço entre a borda das colunas e o conteúdo (default)
x.padding_width = 1

x = PrettyTable()
x.add_column('Nome do Arquivo', nome)
x.add_column('Classificação', predicao)
x.add_column('Comprimento', comprimento)
#x.add_column('Latitude', [])
#x.add_column('Longitude', [])

print(x)
# Out:
# +-----------------+---------------+--------------------+
# | Nome do Arquivo | Classificação |    Comprimento     |
# +-----------------+---------------+--------------------+
# |      solda1     |     solda     | 283.76666666666665 |
# |      solda2     |     solda     | 275.6666666666667  |
# |      solda3     |     solda     |       300.9        |
# |      solda4     |     solda     |       317.9        |
# |      solda5     |     solda     |       229.4        |
# |      solda6     |     solda     | 287.1333333333333  |
# |      solda7     |     solda     |       294.4        |
# |      solda8     |     solda     | 309.96666666666664 |
# |      solda9     |     solda     | 309.3666666666667  |
# |     solda10     |     solda     | 308.06666666666666 |
# |     solda11     |     solda     | 239.76666666666668 |
# |     solda12     |     solda     |       307.6        |
# |     solda13     |     solda     | 258.73333333333335 |
# |     solda14     |     junta     | 302.73333333333335 |
# |     solda15     |     solda     | 326.03333333333336 |
# |     solda16     |     solda     | 249.36666666666667 |
# |     solda17     |     solda     |       151.2        |
# |     solda18     |     solda     |       213.0        |
# |     solda19     |     solda     | 281.56666666666666 |
# |     solda20     |     solda     | 309.6333333333333  |
# |     solda21     |     solda     |       206.4        |
# |     solda22     |     solda     | 199.53333333333333 |
# |     solda23     |     squat     |       326.5        |
# |     solda24     |     solda     |       313.1        |
# |     solda25     |     solda     |       262.6        |
# +-----------------+---------------+--------------------+

# %%
plt.plot(sinalfinal[332])
#sinalmedido.shape[1]
#6en(comprimento)
#len(predicao)

# %%
presidents = ["Washington", "Adams", "Jefferson", "Madison", "Monroe", "Adams", "Jackson"]
#for num, name in enumerate(presidents, start=1):
for num, name in enumerate(presidents): 
    print("President {}: {}".format(num, name))
# Out:
# President 0: Washington
# President 1: Adams
# President 2: Jefferson
# President 3: Madison
# President 4: Monroe
# President 5: Adams
# President 6: Jackson

# %%
len(presidents)
# Out:
# 7

# %%
for x in range(0,35):
  plt.plot(sinalfinal2[:,x])
  plt.show()
